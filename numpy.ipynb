# %%
import numpy as np

a =np.array(6)
b =np.array([2,6,8,5])
c =np.array([[2,4,6],[6,6,7]])
d =np.array([[[4,6,7],[4,6,8]],[[5,7,8],[6,7,8]]])

print(b[1])
print("sum:",b[2]+b[2]+b[1])

print("zero dimentional:",a)
print("1-D:",b)
print("2-D:",c)
print("3-D:",d)

print(a.ndim)
print(b.ndim)
print(c.ndim)
print(d.ndim)

print(c[1,2])
print(d[0,0,1])
# Out:
# 6
# sum: 22
# zero dimentional: 6
# 1-D: [2 6 8 5]
# 2-D: [[2 4 6]
#  [6 6 7]]
# 3-D: [[[4 6 7]
#   [4 6 8]]
#
#  [[5 7 8]
#   [6 7 8]]]
# 0
# 1
# 2
# 3
# 7
# 6

# %%
import matplotlib.pyplot as plt

x = np.array((0,4))
y = np.array((0,4))

plt.plot(x,y)
plt.show()

# %%
from numpy import random

x = random.randint(100)
y = random.randint(100)
print(x)
print(y)
arr = random.randint(100,size=(5))
print(arr)
# Out:
# 2
# 80
# [13 71 47  0  5]

# %%
import numpy as np
import matplotlib.pyplot as pyplot

x = np.array([0,1,2,3,4])
y = np.array([0,1,2,3,4])

plt.plot(x,y, marker = "*")
plt.title("Data_graph")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.grid()
plt.show()

# %%
x_axis =np.array([0,3,5,7])
y_axis =np.array([0,5,8,16])

plt.scatter(x_axis,y_axis,)
plt.show()

# %%
x_axis =np.array(["Apples","Banana","Chocolate","Vanilla"])
y_axis =np.array([4,15,20,2])

plt.bar(x,y,width =0.4)
plt.show()

# %%
x_axis =np.array(["Apples","Banana","Chocolate","Vanilla"])
y_axis =np.array([4,15,20,2])

plt.barh(x,y,height = 0.5, color="green",)
plt.show()

# %%
x = np.array([70,50,10,90])
my_labels =("BMW","Jeep","Toyota","Volvo")
my_colors =("green","purple","black","yellow")

plt.pie(x, labels=my_labels, colors=my_colors)
plt.show()

# %%
import numpy as np
from numpy import random
import matplotlib.pyplot as plt

x = random.randint(100, size =(5))
y = random.randint(100, size =(5))

print(x)
print(y)

plt.plot(x,y)
plt.show()
# Out:
# [74 57 65 68 21]
# [24 13 31  9 88]

# %%
import pandas as pd

a = [4,5,6,7]
table=pd.Series(a,index=("Day1","Day2","Day3","Day4"))

print(table)
# Out:
# Day1    4
# Day2    5
# Day3    6
# Day4    7
# dtype: int64

# %%
import pandas as pd

a = {
    "new":[4,5,6],
    "month":["Jan","Feb","Mar"]
    }
tab = pd.DataFrame(a)
print(tab)
# Out:
#    new month
# 0    4   Jan
# 1    5   Feb
# 2    6   Mar

# %%
import pandas as pd
import matplotlib.pyplot as plt

# with open("data.csv") as data:
#     contents=data.read()
#     print(contents)

contents=pd.read_csv("data.csv")
print(contents)

# Plotting with pandas
contents.plot()
plt.show()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# with open("data.csv") as data:
#     contents=data.read()
#     print(contents)

contents=pd.read_csv("data.csv")
print(contents)

# Plotting with pandas
contents.plot('Duration','Pulse')
plt.show()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# with open("data.csv") as data:
#     contents=data.read()
#     print(contents)

contents=pd.read_csv("data.csv")
print(contents)

# Plotting with pandas
contents.plot(kind='scatter',x='Duration',y='Pulse')
plt.show()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
